# %% [markdown]
# Imbalanced Dataset:
# A dataset with unequal class distribution
# ex : suppose in a diabete datset we have 1000 data points of non-diabetic person and only 100 data points of diabatic person

# %%
import pandas as pd
import numpy as np

# %%
credit_card_data = pd.read_csv("/content/credit_data.csv")

# %%
credit_card_data.shape
# Out:
# (73377, 31)

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# last 5 rows of dataset
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 73372  55105  1.104021 -1.123835  1.008939 -0.460960 -1.502758  0.021138
# 73373  55105  1.182898 -0.283273  1.123494  0.066948 -1.283276 -0.900451
# 73374  55106  1.168124 -0.122507  1.251822  0.860341 -1.020137 -0.277310
# 73375  55106 -0.339385 -2.095670  0.271543 -3.066469  0.484794  3.870704
# 73376  55107 -1.020407  0.160171  0.152264 -0.093406 -0.978017  0.074549
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 73372 -1.055043  0.095135 -0.175413  ...  0.405906  1.054006 -0.174455
# 73373 -0.441870 -0.150647  0.784691  ...  0.082278  0.491790 -0.025468
# 73374 -0.557856  0.023732  0.802378  ... -0.077921 -0.005984  0.014309
# 73375 -2.069399  0.184347 -1.615958  ...  0.964115 -0.266112 -0.993763
# 73376  1.610152  0.117407 -0.948643  ...  0.109380 -0.400171  0.835422
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# distribution of the two classes
credit_card_data["Class"].value_counts()
# Out:
# Class
# 0.0    73198
# 1.0      178
# Name: count, dtype: int64

# %% [markdown]
# This is highly inbalnced data set

# %% [markdown]
# 0--> Legit transctions
# 1--> Fraudulent transactions

# %%
# separating the legit and fraudulent transaction
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
legit.shape
# Out:
# (73198, 31)

# %%
fraud.shape
# Out:
# (178, 31)

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Buid a sample dataset containing similar distribution of Legit and Fraudulent transactons

# %% [markdown]
# Number of fraudulent transactons : 178

# %%
legit_sample = legit.sample(n=178)

# %%
print(legit_sample.shape)
# Out:
# (178, 31)

# %% [markdown]
# Concatenate two data frames

# %%
new_credit_card_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_credit_card_dataset.shape
# Out:
# (356, 31)

# %%
new_credit_card_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 37291  38895 -0.881081  0.219706  1.619924 -0.545692  1.353764 -0.886284
# 18516  29560  1.350967 -0.721958 -0.334705 -1.049059 -0.247971  0.269552
# 47852  43389  1.084320 -1.237842  1.022659 -0.508855 -1.738414 -0.145324
# 41141  40555  1.045278 -0.303990 -0.488719  0.013595 -0.150374 -0.871170
# 5856    6368 -1.425079  0.330939  2.312133 -2.715652 -0.476413 -0.750138
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 37291  0.632757 -0.261069 -0.353389  ... -0.217760 -0.712651 -0.103660
# 18516 -0.590564  0.118119 -0.931101  ...  0.225348  0.461017 -0.261345
# 47852 -1.141654  0.163718 -0.265756  ...  0.423219  0.956203 -0.212341
# 41141  0.472007 -0.238758 -0.330529  ...  0.057221 -0.169345 -0.251322
# 5856   0.014072 -0.074900  3.379051  ... -0.081584  0.470853 -0.320473
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_credit_card_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
# 72757  54846 -2.986466 -0.000891  0.605887  0.338338  0.685448 -1.581954
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 69498 -2.582865  0.643230 -1.191233  ...  0.594623  0.372144 -0.310456
# 69980 -2.340991  0.713004 -1.416265  ...  0.383180 -0.213952 -0.336640
# 70141 -2.355254  0.854659 -1.281243  ...  0.679176  0.731907  0.333045
# 70589 -3.039520 -1.634233 -0.594809  ... -0.723326  0.501222 -0.696892
# 72757  0.504206 -0.233403  0.636768  ... -0.875146 -0.509849  1.313918
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_credit_card_dataset["Class"].value_counts()
# Out:
# Class
# 0.0    178
# 1.0    178
# Name: count, dtype: int64
